# %% [markdown]
# # Introduction
# This notebook contains the basic usage of keras and sklearn on MNIST
# There are 5 steps.
#
# 1. Stratified shuffling split on training data set
# 2. Training and validating a CNN
# 3. Confusion matrix
# 4. Convolution fileter visualization
# 5. Saliency map
#
# There are 2 outputs
#
# 1. Prediction csv on testing data
# 2. Keras model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %matplotlib inline
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import matplotlib.pyplot as plt
import seaborn as sns


from subprocess import check_output
print(check_output(["ls", "/path/to/data/mnist_data/"]).decode("utf8"))
# Out:
# test.csv
# train.csv

# %%
# !pip install yprov4ml
# Out:
# Requirement already satisfied: yprov4ml in /usr/local/lib/python3.12/dist-packages (2.0.3)
# Requirement already satisfied: codecarbon>=2.8 in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (3.1.1)
# Requirement already satisfied: fvcore in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (0.1.5.post20221221)
# Requirement already satisfied: geocoder in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (1.38.1)
# Requirement already satisfied: gpustat in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (1.1.1)
# Requirement already satisfied: GPUtil in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (1.4.0)
# Requirement already satisfied: lightning in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (2.5.6)
# Requirement already satisfied: netCDF4 in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (2.0.2)
# Requirement already satisfied: nvitop in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (1.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (2.2.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (7.1.3)
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (4.0.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (0.24.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (4.67.1)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (4.15.0)
# Requirement already satisfied: rocrate in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (0.14.2)
# Requirement already satisfied: aenum in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (3.1.16)
# Requirement already satisfied: prov in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (2.1.1)
# Requirement already satisfied: zarr in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (3.1.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (6.0.2)
# Requirement already satisfied: rdflib<7 in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (6.3.2)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from yprov4ml) (13.580.82)
# Requirement already satisfied: arrow in /usr/local/lib/python3.12/dist-packages (from codecarbon>=2.8->yprov4ml) (1.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from codecarbon>=2.8->yprov4ml) (8.3.1)
# Requirement already satisfied: fief-client[cli] in /usr/local/lib/python3.12/dist-packages (from codecarbon>=2.8->yprov4ml) (0.20.0)
# Requirement already satisfied: prometheus_client in /usr/local/lib/python3.12/dist-packages (from codecarbon>=2.8->yprov4ml) (0.23.1)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from codecarbon>=2.8->yprov4ml) (9.0.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from codecarbon>=2.8->yprov4ml) (2.11.10)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.12/dist-packages (from codecarbon>=2.8->yprov4ml) (3.14.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from codecarbon>=2.8->yprov4ml) (2.32.4)
# Requirement already satisfied: questionary in /usr/local/lib/python3.12/dist-packages (from codecarbon>=2.8->yprov4ml) (2.1.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from codecarbon>=2.8->yprov4ml) (13.9.4)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from codecarbon>=2.8->yprov4ml) (0.20.0)
# Requirement already satisfied: isodate<0.7.0,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from rdflib<7->yprov4ml) (0.6.1)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from rdflib<7->yprov4ml) (3.2.5)
# Requirement already satisfied: yacs>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from fvcore->yprov4ml) (0.1.8)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from fvcore->yprov4ml) (6.0.3)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.12/dist-packages (from fvcore->yprov4ml) (3.2.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from fvcore->yprov4ml) (11.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from fvcore->yprov4ml) (0.9.0)
# Requirement already satisfied: iopath>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from fvcore->yprov4ml) (0.1.10)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from geocoder->yprov4ml) (1.0.0)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.12/dist-packages (from geocoder->yprov4ml) (0.1.6)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from geocoder->yprov4ml) (1.17.0)
# Requirement already satisfied: blessed>=1.17.1 in /usr/local/lib/python3.12/dist-packages (from gpustat->yprov4ml) (1.25.0)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning->yprov4ml) (2025.3.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning->yprov4ml) (0.15.2)
# Requirement already satisfied: packaging<27.0,>=20.0 in /usr/local/lib/python3.12/dist-packages (from lightning->yprov4ml) (25.0)
# Requirement already satisfied: torchmetrics<3.0,>0.7.0 in /usr/local/lib/python3.12/dist-packages (from lightning->yprov4ml) (1.8.2)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.12/dist-packages (from lightning->yprov4ml) (2.5.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->yprov4ml) (3.5.0)
# Requirement already satisfied: cftime in /usr/local/lib/python3.12/dist-packages (from netCDF4->yprov4ml) (1.6.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netCDF4->yprov4ml) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->yprov4ml) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->yprov4ml) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->yprov4ml) (2025.2)
# Requirement already satisfied: arcp==0.2.1 in /usr/local/lib/python3.12/dist-packages (from rocrate->yprov4ml) (0.2.1)
# Requirement already satisfied: donfig>=0.8 in /usr/local/lib/python3.12/dist-packages (from zarr->yprov4ml) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr->yprov4ml) (1.7.1)
# Requirement already satisfied: numcodecs>=0.14 in /usr/local/lib/python3.12/dist-packages (from zarr->yprov4ml) (0.16.5)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.12/dist-packages (from blessed>=1.17.1->gpustat->yprov4ml) (0.2.14)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning->yprov4ml) (3.13.2)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from iopath>=0.1.7->fvcore->yprov4ml) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->yprov4ml) (1.3.0)
# Requirement already satisfied: httpx<0.28.0,>=0.21.3 in /usr/local/lib/python3.12/dist-packages (from fief-client[cli]->codecarbon>=2.8->yprov4ml) (0.27.2)
# Requirement already satisfied: jwcrypto<2.0.0,>=1.4 in /usr/local/lib/python3.12/dist-packages (from fief-client[cli]->codecarbon>=2.8->yprov4ml) (1.5.6)
# Requirement already satisfied: yaspin in /usr/local/lib/python3.12/dist-packages (from fief-client[cli]->codecarbon>=2.8->yprov4ml) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->yprov4ml) (3.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->codecarbon>=2.8->yprov4ml) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->codecarbon>=2.8->yprov4ml) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->codecarbon>=2.8->yprov4ml) (0.4.2)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from questionary->codecarbon>=2.8->yprov4ml) (3.0.52)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ratelim->geocoder->yprov4ml) (4.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->codecarbon>=2.8->yprov4ml) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->codecarbon>=2.8->yprov4ml) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->codecarbon>=2.8->yprov4ml) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->codecarbon>=2.8->yprov4ml) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->codecarbon>=2.8->yprov4ml) (2.19.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->codecarbon>=2.8->yprov4ml) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->yprov4ml) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->yprov4ml) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->yprov4ml) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->yprov4ml) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->yprov4ml) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->yprov4ml) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning->yprov4ml) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon>=2.8->yprov4ml) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon>=2.8->yprov4ml) (1.0.9)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon>=2.8->yprov4ml) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.21.3->fief-client[cli]->codecarbon>=2.8->yprov4ml) (0.16.0)
# Requirement already satisfied: cryptography>=3.4 in /usr/local/lib/python3.12/dist-packages (from jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon>=2.8->yprov4ml) (43.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->codecarbon>=2.8->yprov4ml) (0.1.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon>=2.8->yprov4ml) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.4->jwcrypto<2.0.0,>=1.4->fief-client[cli]->codecarbon>=2.8->yprov4ml) (2.23)

# %%
import yprov4ml

# %%
# Start the provenance run
yprov4ml.start_run(
    prov_user_namespace="www.example.og",
    experiment_name="saliency_mapping",
    provenance_save_dir="/content/"
)
# Out:
# [codecarbon WARNING @ 12:42:39] Multiple instances of codecarbon are allowed to run at the same time.

# %%
# read input csv file
train_df = pd.read_csv('/path/to/data/mnist_data/train.csv')
test_df = pd.read_csv('/path/to/data/mnist_data/test.csv')

# %%
X_train = []
Y_train = []
X_test = []

# reshape training data from rows into images
for index, row in train_df.iterrows():
    X_train.append(row.values[1 : ].reshape((28, 28, 1)))
    Y_train.append(row['label'])

# reshape testing data from rows into images
for index, row in test_df.iterrows():
    X_test.append(row.values.reshape((28, 28, 1)))

# normalization
X_train = np.array(X_train) / 255.
Y_train = np.array(Y_train)
X_test = np.array(X_test) / 255.

print('There are', X_train.shape[0], 'training data and', X_test.shape[0], 'testing data')
print('Number of occurence for each number in training data (0 stands for 10):')
print(np.vstack((np.unique(Y_train), np.bincount(Y_train))).T)
sns.countplot(Y_train)
# Out:
# There are 42000 training data and 28000 testing data
# Number of occurence for each number in training data (0 stands for 10):
# [[   0 4132]
#  [   1 4684]
#  [   2 4177]
#  [   3 4351]
#  [   4 4072]
#  [   5 3795]
#  [   6 4137]
#  [   7 4401]
#  [   8 4063]
#  [   9 4188]]
# <Axes: ylabel='count'>

# %%
# plot first 36 images in MNIST
fig, ax = plt.subplots(6, 6, figsize = (12, 12))
fig.suptitle('First 36 images in MNIST')
fig.tight_layout(pad = 0.3, rect = [0, 0, 0.9, 0.9])
for x, y in [(i, j) for i in range(6) for j in range(6)]:
    ax[x, y].imshow(X_train[x + y * 6].reshape((28, 28)), cmap = 'gray')
    ax[x, y].set_title(Y_train[x + y * 6])

# %%
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn import preprocessing

# transform training label to one-hot encoding
lb = preprocessing.LabelBinarizer()
lb.fit(Y_train)
Y_train = lb.transform(Y_train)

# split training and validating data
print('Stratified shuffling...')
sss = StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=15)
for train_idx, val_idx in sss.split(X_train, Y_train):
    X_train_tmp, X_val = X_train[train_idx], X_train[val_idx]
    Y_train_tmp, Y_val = Y_train[train_idx], Y_train[val_idx]

X_train = X_train_tmp
Y_train = Y_train_tmp
print('Finish stratified shuffling...')
# Out:
# Stratified shuffling...
# Finish stratified shuffling...

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

img_size = (28, 28, 1)
n_classes = 10

if os.path.exists('keras_model.h5'):
    print('Loading model...')
    model = load_model('keras_model.h5')
else:
    print('Building model...')
    model = Sequential()
    model.add(Conv2D(32, (5, 5), input_shape = img_size, kernel_initializer = 'normal'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Conv2D(64, (5, 5), kernel_initializer = 'normal'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(n_classes))
    model.add(Activation('softmax'))

    model.compile(loss = 'categorical_crossentropy', optimizer = 'rmsprop', metrics = ['accuracy'])
# Out:
# Building model...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# data augmentation
datagen = ImageDataGenerator(
    featurewise_center = False,
    samplewise_center = False,
    featurewise_std_normalization = False,
    samplewise_std_normalization = False,
    zca_whitening = False,
    rotation_range = 0,
    zoom_range = 0.1,
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    horizontal_flip = False,
    vertical_flip = False
)

datagen.fit(X_train)

# %%
print('Training model...')
model.fit(datagen.flow(X_train, Y_train, batch_size = 1000),
                   epochs = 20,
                   validation_data = (X_val, Y_val),
                   steps_per_epoch = int(X_train.shape[0] / 1000),
                   verbose = 1)
print('Validating model...')
score, acc = model.evaluate(X_val, Y_val, verbose = 1)
print('\nLoss:', score, '\nAcc:', acc)
model.save('keras_model.h5')
# Out:
# Training model...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.3602 - loss: 1.8267 - val_accuracy: 0.8620 - val_loss: 0.4647
# Epoch 2/20
#  1/33 ━━━━━━━━━━━━━━━━━━━━ 28s 904ms/step - accuracy: 0.6490 - loss: 1.0049
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.6490 - loss: 1.0049 - val_accuracy: 0.8690 - val_loss: 0.4720
# Epoch 3/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.7544 - loss: 0.7855 - val_accuracy: 0.9363 - val_loss: 0.2226
# Epoch 4/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 86ms/step - accuracy: 0.8430 - loss: 0.5143 - val_accuracy: 0.9495 - val_loss: 0.1947
# Epoch 5/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.8526 - loss: 0.4771 - val_accuracy: 0.9519 - val_loss: 0.1575
# Epoch 6/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.8760 - loss: 0.3830 - val_accuracy: 0.9496 - val_loss: 0.1762
# Epoch 7/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.8805 - loss: 0.3875 - val_accuracy: 0.9688 - val_loss: 0.1074
# Epoch 8/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 161ms/step - accuracy: 0.9200 - loss: 0.2659 - val_accuracy: 0.9700 - val_loss: 0.0997
# Epoch 9/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.9095 - loss: 0.2988 - val_accuracy: 0.9711 - val_loss: 0.0961
# Epoch 10/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.9180 - loss: 0.2328 - val_accuracy: 0.9567 - val_loss: 0.1291
# Epoch 11/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.9208 - loss: 0.2577 - val_accuracy: 0.9707 - val_loss: 0.0957
# Epoch 12/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.9330 - loss: 0.2256 - val_accuracy: 0.9746 - val_loss: 0.0832
# Epoch 13/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.9370 - loss: 0.2107 - val_accuracy: 0.9792 - val_loss: 0.0706
# Epoch 14/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 161ms/step - accuracy: 0.9400 - loss: 0.1936 - val_accuracy: 0.9780 - val_loss: 0.0717
# Epoch 15/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - accuracy: 0.9448 - loss: 0.1815 - val_accuracy: 0.9793 - val_loss: 0.0681
# Epoch 16/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.9630 - loss: 0.1486 - val_accuracy: 0.9788 - val_loss: 0.0696
# Epoch 17/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9513 - loss: 0.1591 - val_accuracy: 0.9811 - val_loss: 0.0599
# Epoch 18/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - accuracy: 0.9620 - loss: 0.1368 - val_accuracy: 0.9827 - val_loss: 0.0582
# Epoch 19/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - accuracy: 0.9564 - loss: 0.1458 - val_accuracy: 0.9818 - val_loss: 0.0575
# Epoch 20/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 161ms/step - accuracy: 0.9540 - loss: 0.1839 - val_accuracy: 0.9808 - val_loss: 0.0650
# Validating model...
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9814 - loss: 0.0706
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Loss: 0.06504915654659271
# Acc: 0.9808333516120911

# %%
yprov4ml.log_artifact("Classifier", "keras_model.h5")
# Out:
# <ProvEntity: keras_model.h5>

# %%
print('Predicting...')
Y_test = model.predict(X_test)
Y_test = lb.inverse_transform(Y_test)
Y_test = [[y] for y in Y_test]
index = [[i] for i in range(1, X_test.shape[0] + 1)]
output_np = np.concatenate((index, Y_test), axis = 1)
output_df = pd.DataFrame(data = output_np, columns = ['ImageId', 'Label'])
output_df.to_csv('out.csv', index = False)
# Out:
# Predicting...
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step

# %%
from sklearn.metrics import confusion_matrix
import itertools

Y_pred = model.predict(X_val)
Y_val_pred = lb.inverse_transform(Y_pred)
Y_val_real = lb.inverse_transform(Y_val)
cm = confusion_matrix(Y_val_real, Y_val_pred)
cm = cm.astype('float') / cm.sum(axis = 1)[:, np.newaxis]

# print(cm)
plt.imshow(cm, cmap = 'gray')
plt.title('Normalized confusion matrix')
plt.colorbar()
tick_marks = np.arange(n_classes)
plt.xticks(tick_marks, np.arange(n_classes), rotation=45)
plt.yticks(tick_marks, np.arange(n_classes))

fmt = '.2f'
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
             horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# Text(0.5, 21.34715460257995, 'Predicted label')

# %%
# Visualizating filters
# https://blog.keras.io/how-convolutional-neural-networks-see-the-world.html
from keras import backend as K
import tensorflow as tf

model = load_model('keras_model.h5')

layer_dict = dict([(layer.name, layer) for layer in model.layers])
#print('Layer dict', layer_dict)
print(model.summary())
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 24, 24, 32)     │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 8, 8, 64)       │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 184,588 (721.05 KB)
#  Trainable params: 184,586 (721.04 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)
# None

# %%
# util function to convert a tensor into a valid image
def deprocess_image(x):
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1

    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)

    # convert to RGB array
    x *= 255
    #x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

def vis_img_in_filter(img = np.array(X_train[0]).reshape((1, 28, 28, 1)).astype(np.float64),
                      layer_name = 'conv2d'):
    layer_output = layer_dict[layer_name].output
    img_ascs = list()
    for filter_index in range(layer_output.shape[3]):
        # build a loss function that maximizes the activation
        # of the nth filter of the layer considered
        # loss = tf.reduce_mean(layer_output[:, :, :, filter_index])

        # compute the gradient of the input picture wrt this loss
        # grads = tf.gradients(loss, model.input)[0]

        # normalization trick: we normalize the gradient
        # grads /= (tf.sqrt(tf.reduce_mean(tf.square(grads))) + 1e-5)

        # this function returns the loss and grads given the input picture
        # iterate = K.function([model.input], [loss, grads])
        @tf.function
        def iterate(x):
            with tf.GradientTape() as tape:
                tape.watch(x)
                activation = layer_dict[layer_name](x)
                loss = tf.reduce_mean(activation[:, :, :, filter_index])
            grads = tape.gradient(loss, x)[0]
            grads /= (tf.sqrt(tf.reduce_mean(tf.square(grads))) + 1e-5)
            return loss, grads


        # step size for gradient ascent
        step = 5.

        img_asc = np.array(img)
        # run gradient ascent for 20 steps
        for i in range(20):
            # Convert numpy array to TensorFlow tensor
            img_asc_tensor = tf.constant(img_asc, dtype=tf.float32)
            loss_value, grads_value = iterate(img_asc_tensor)
            img_asc += grads_value.numpy() * step # Convert gradients back to numpy

        img_asc = img_asc[0]
        img_ascs.append(deprocess_image(img_asc).reshape((28, 28)))

    if layer_output.shape[3] >= 35:
        plot_x, plot_y = 6, 6
    elif layer_output.shape[3] >= 23:
        plot_x, plot_y = 4, 6
    elif layer_output.shape[3] >= 11:
        plot_x, plot_y = 2, 6
    else:
        plot_x, plot_y = 1, 2
    fig, ax = plt.subplots(plot_x, plot_y, figsize = (12, 12))
    ax[0, 0].imshow(img.reshape((28, 28)), cmap = 'gray')
    ax[0, 0].set_title('Input image')
    fig.suptitle('Input image and %s filters' % (layer_name,))
    fig.tight_layout(pad = 0.3, rect = [0, 0, 0.9, 0.9])
    for (x, y) in [(i, j) for i in range(plot_x) for j in range(plot_y)]:
        if x == 0 and y == 0:
            continue
        ax[x, y].imshow(img_ascs[x * plot_y + y - 1], cmap = 'gray')
        ax[x, y].set_title('filter %d' % (x * plot_y + y - 1))

vis_img_in_filter()

# %%
# Saliency map
# https://github.com/experiencor/deep-viz-keras/blob/master/saliency.py
from keras.layers import Input, Conv2DTranspose
from keras.models import Model
from keras.initializers import Ones, Zeros
import tensorflow as tf
import numpy as np # Import numpy
import os # Import os

class SaliencyMask(object):
    def __init__(self, model, output_index=0):
        self.model = model
        self.output_index = output_index

    def get_mask(self, input_image):
        pass

    def get_smoothed_mask(self, input_image, stdev_spread=.2, nsamples=50):
        stdev = stdev_spread * (np.max(input_image) - np.min(input_image))

        total_gradients = np.zeros_like(input_image, dtype = np.float64)
        for i in range(nsamples):
            noise = np.random.normal(0, stdev, input_image.shape)
            x_value_plus_noise = input_image + noise

            total_gradients += self.get_mask(x_value_plus_noise)

        return total_gradients / nsamples

class GradientSaliency(SaliencyMask):

    def get_mask(self, input_image):
        x_value = np.expand_dims(input_image, axis=0)
        x_value_tensor = tf.constant(x_value, dtype=tf.float32)

        with tf.GradientTape() as tape:
            tape.watch(x_value_tensor)
            predictions = self.model(x_value_tensor)
            loss = predictions[:, self.output_index]

        gradients = tape.gradient(loss, x_value_tensor)[0]

        # Save gradients to a temporary file and log the path
        temp_file_path = "/content/gradients.npy"
        np.save(temp_file_path, gradients.numpy())
        yprov4ml.log_artifact("GradientSaliency", temp_file_path)

        return gradients.numpy()


# https://github.com/experiencor/deep-viz-keras/blob/master/visual_backprop.py
class VisualBackprop(SaliencyMask):
    def __init__(self, model, output_index = 0):
        inps = [model.input]           # input placeholder
        outs = [layer.output for layer in model.layers]    # all layer outputs
        self.forward_pass = K.function(inps, outs)         # evaluation function

        self.model = model

    def get_mask(self, input_image):
        x_value = np.expand_dims(input_image, axis=0)

        visual_bpr = None
        layer_outs = self.forward_pass([x_value, 0])

        for i in range(len(self.model.layers) - 1, -1, -1):
            if 'Conv2D' in str(type(self.model.layers[i])):
                layer = np.mean(layer_outs[i], axis = 3, keepdims = True)
                layer = layer - np.min(layer)
                layer = layer / (np.max(layer) - np.min(layer) + 1e-6)

                if visual_bpr is not None:
                    if visual_bpr.shape != layer.shape:
                        visual_bpr = self._deconv(visual_bpr)
                    visual_bpr = visual_bpr * layer
                else:
                    visual_bpr = layer
        yprov4ml.log_artifact("VisualBackprop", visual_bpr[0])
        return visual_bpr[0]

    def _deconv(self, feature_map):
        x = Input(shape = (None, None, 1))
        y = Conv2DTranspose(filters = 1,
                            kernel_size = (3, 3),
                            strides = (2, 2),
                            padding = 'same',
                            kernel_initializer = Ones(),
                            bias_initializer = Zeros())(x)

        deconv_model = Model(inputs=[x], outputs=[y])

        inps = [deconv_model.input]   # input placeholder
        outs = [deconv_model.layers[-1].output]           # output placeholder
        deconv_func = K.function(inps, outs)              # evaluation function

        return deconv_func([feature_map, 0])[0]

# %%
Y_train_label = lb.inverse_transform(Y_train)

fig, ax = plt.subplots(10, 5, figsize = (20, 24)) # Increased figsize for better spacing
fig.suptitle('vanilla gradient')
for i in range(n_classes):
    img = np.array(X_train[i])

    # Build the model by calling it with a sample input
    model(tf.keras.Input(shape=(28, 28, 1)))

    vanilla = GradientSaliency(model, Y_train_label[i])
    mask = vanilla.get_mask(img)
    filter_mask = (mask > 0.0).reshape((28, 28))
    smooth_mask = vanilla.get_smoothed_mask(img)
    filter_smoothed_mask = (smooth_mask > 0.0).reshape((28, 28))

    ax[i, 0].imshow(img.reshape((28, 28)), cmap = 'gray')
    cax = ax[i, 1].imshow(mask.reshape((28, 28)), cmap = 'jet')
    fig.colorbar(cax, ax = ax[i, 1])
    ax[i, 2].imshow(mask.reshape((28, 28)) * filter_mask, cmap = 'gray')
    cax = ax[i, 3].imshow(mask.reshape((28, 28)), cmap = 'jet')
    fig.colorbar(cax, ax = ax[i, 3])
    ax[i, 4].imshow(smooth_mask.reshape((28, 28)) * filter_smoothed_mask, cmap = 'gray')

# %%
# End run
yprov4ml.end_run(create_graph=True, create_svg=True)
